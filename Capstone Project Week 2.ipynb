# %% [markdown]
# **A description of the problem and a discussion of the background**
#
# *The background and problem*
#
# ABC, a company based in Toronto, is responsible for organizing corporate retreat events. The company must put together a list tailored for their clients needs that includes hotels for their stay, halls for meetings/presentations, nearby parks for down time, nearby restaurants.
#
# *Data description*
#
# I will utilize data provided by Foursquare location data. The data will be grouped by area, and include the information about the area and hotels, parks and restaurants.
#
# This was allow clients to pick the area of the city that is best for them, so that they have good access to resturants and parks during their stay.

# %% [markdown]
# Table of contents
#
# 01- Import Libraries
#
# 02- Define Foursquare Credentials
#
# 03- Define the city & get latitude & longitude
#
# 04- Search for Hotels & clean dataframe
#
# 05- Search for Parks & clean dataframe
#
# 06- Search for Restaurants & clean dataframe
#
# 07- Generate map to visualize hotels, parks and restaurants and how they cluster together

# %% [markdown]
# **Import Libraries**

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
# module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
# plotting library
# Out:
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# **Define Foursquare Credentials**

# %%
ClIENT_ID = 'G3PM1X3BYS0RGSYFU0PUEIS0XQV3OLXKX00UGE1AANRJIQQP' # Foursquare ID
ClIENT_SECRET = 'U3EMAUUDX5H343WX41RCCVANFDAVJSQHE0RVN4INQGN2TGUC' #  Foursquare Secret
VERSION = '20190611'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: G3PM1X3BYS0RGSYFU0PUEIS0XQV3OLXKX00UGE1AANRJIQQP
# Foursquare_Secret:U3EMAUUDX5H343WX41RCCVANFDAVJSQHE0RVN4INQGN2TGUC

# %% [markdown]
# **Define the city & get latitude & longitude**

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# **Search for Hotels**

# %%
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G3PM1X3BYS0RGSYFU0PUEIS0XQV3OLXKX00UGE1AANRJIQQP&client_secret=U3EMAUUDX5H343WX41RCCVANFDAVJSQHE0RVN4INQGN2TGUC&ll=43.653963,-79.387207&v=20190611&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  58b7d72dcc05d161570bd712  123 Queen Street West          CA       Toronto
# 3  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 4  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                416
# 1           Canada  Queen & St. Patrick                400
# 2           Canada                  NaN                410
# 3           Canada          Dundas St W                124
# 4           Canada      at somewhere St                500
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65112928325278...     43.651129
# 1  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 2  [{'label': 'display', 'lat': 43.65101646682632...     43.651016
# 3  [{'label': 'display', 'lat': 43.6546083, 'lng'...     43.654608
# 4  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.383829                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.384148                   NaN             M5H 2M9             ON
# 3    -79.385942                   NaN             M5G 1R3             ON
# 4    -79.387894                   NaN             M2M 2M2             ON
#
#                                           name    referralId venuePage.id
# 0                Sheraton Centre Toronto Hotel  v-1560280421          NaN
# 1               The Rex Hotel Jazz & Blues Bar  v-1560280421     62225795
# 2                Sheraton Centre Toronto Hotel  v-1560280421    402127087
# 3  DoubleTree by Hilton Hotel Toronto Downtown  v-1560280421          NaN
# 4                               VFM Test Hotel  v-1560280421          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                           name categories  \
# 0                Sheraton Centre Toronto Hotel      Hotel
# 1               The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2                Sheraton Centre Toronto Hotel      Hotel
# 3  DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 4                               VFM Test Hotel      Hotel
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       416
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2  123 Queen Street West  CA  Toronto  Canada                  NaN       410
# 3    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 4         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65112928325278...  43.651129 -79.383829
# 1  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 2  [{'label': 'display', 'lat': 43.65101646682632...  43.651016 -79.384148
# 3  [{'label': 'display', 'lat': 43.6546083, 'lng'...  43.654608 -79.385942
# 4  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
#
#   neighborhood postalCode state                        id
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1          NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2          NaN    M5H 2M9    ON  58b7d72dcc05d161570bd712
# 3          NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 4          NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                    Sheraton Centre Toronto Hotel                   Hotel
# 3      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                   VFM Test Hotel                   Hotel
# 5   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 6                                  Stathcona Hotel                   Hotel
# 7    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 8                                        650 Hotel                   Hotel
# 9                                Be SixFifty Hotel                   Hotel
# 10                                  Hilton Toronto                   Hotel
# 11                           89 Chestnut Residence  College Residence Hall
# 12    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 13          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 14                              Shangri-La Toronto                   Hotel
# 15                   Op mijn hotelkamer In Toronto                   Hotel
# 16                                  Fitness Centre                     Gym
# 17                                  Fitness Centre                     Gym
# 18                                            Pool                    Pool
# 19                                   Kumar For Men             Men's Store
# 20                                  Grand Ballroom             Event Space
# 21                                   Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9       ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 5   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 6                     NaN  43.654947 -79.386359        NaN       ON
# 7   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 8          650 Bay Street  43.657046 -79.384411        NaN       ON
# 9          650 Bay Street  43.657120 -79.384560        NaN       ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2       ON
# 11        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 13    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 14    188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 15                    NaN  43.654235 -79.386208        NaN       ON
# 16        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 17            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 18       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 19        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON
# 21        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                  Sheraton Centre Toronto Hotel                   Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                 VFM Test Hotel                   Hotel
# 10                                Hilton Toronto                   Hotel
# 11                         89 Chestnut Residence  College Residence Hall
# 12  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 13        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 14                            Shangri-La Toronto                   Hotel
# 16                                Fitness Centre                     Gym
# 17                                Fitness Centre                     Gym
# 19                                 Kumar For Men             Men's Store
# 20                                Grand Ballroom             Event Space
# 21                                 Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 11        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 13    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 14    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 16        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 17            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 19        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 21        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 10                                Hilton Toronto        Hotel
# 12  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 14                            Shangri-La Toronto        Hotel
# 20                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 14    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 10                                Hilton Toronto        Hotel
# 12  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 14                            Shangri-La Toronto        Hotel
# 20                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 14    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 20                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651129 -79.383829    M5H 2M9    ON
# 20  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# **Search for Parks**

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G3PM1X3BYS0RGSYFU0PUEIS0XQV3OLXKX00UGE1AANRJIQQP&client_secret=U3EMAUUDX5H343WX41RCCVANFDAVJSQHE0RVN4INQGN2TGUC&ll=43.653963,-79.387207&v=20190611&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
#
#                          id    location.address location.cc location.city  \
# 0  4b170e47f964a5208cc123e3  691 University Ave          CA       Toronto
# 1  4b54deadf964a520a3d027e3                 NaN          CA       Toronto
# 2  59ddd7469ba3e51a75459568    382 Yonge Street          CA       Toronto
# 3  4bb3c91a2397b7134d9f38b3         Spadina Ave          CA       Toronto
# 4  4ad80fcef964a520a61021e3       280 Simcoe St          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada        at College St                716
# 1           Canada                  NaN                423
# 2           Canada                  NaN                695
# 3           Canada   at Wellington St W               1223
# 4           Canada   Dundas Street West                282
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2     [382 Yonge Street, Toronto ON M5G 1S8, Canada]
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4  [280 Simcoe St (Dundas Street West), Toronto O...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.6592634, 'lng'...     43.659263
# 3  [{'label': 'display', 'lat': 43.64422227794523...     43.644222
# 4  [{'label': 'display', 'lat': 43.65544241747622...     43.655442
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.382632             M5G 1S8             ON
# 3    -79.394230                 NaN             ON
# 4    -79.390056             M5T 2Y5             ON
#
#                             name    referralId venuePage.id
# 0    Queen's Park Subway Station  v-1560280600          NaN
# 1                    Grange Park  v-1560280600          NaN
# 2  Crunch Fitness - College Park  v-1560280600    532736199
# 3           Clarence Square Park  v-1560280600          NaN
# 4                  One Park Lane  v-1560280600          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                             name                                categories  \
# 0    Queen's Park Subway Station                             Metro Station
# 1                    Grange Park                                      Park
# 2  Crunch Fitness - College Park                      Gym / Fitness Center
# 3           Clarence Square Park                                      Park
# 4                  One Park Lane  Residential Building (Apartment / Condo)
#
#               address  cc     city country         crossStreet  distance  \
# 0  691 University Ave  CA  Toronto  Canada       at College St       716
# 1                 NaN  CA  Toronto  Canada                 NaN       423
# 2    382 Yonge Street  CA  Toronto  Canada                 NaN       695
# 3         Spadina Ave  CA  Toronto  Canada  at Wellington St W      1223
# 4       280 Simcoe St  CA  Toronto  Canada  Dundas Street West       282
#
#                                     formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2     [382 Yonge Street, Toronto ON M5G 1S8, Canada]
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4  [280 Simcoe St (Dundas Street West), Toronto O...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.6592634, 'lng'...  43.659263 -79.382632
# 3  [{'label': 'display', 'lat': 43.64422227794523...  43.644222 -79.394230
# 4  [{'label': 'display', 'lat': 43.65544241747622...  43.655442 -79.390056
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2    M5G 1S8    ON  59ddd7469ba3e51a75459568
# 3        NaN    ON  4bb3c91a2397b7134d9f38b3
# 4    M5T 2Y5    ON  4ad80fcef964a520a61021e3

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                    name  \
# 0           Queen's Park Subway Station
# 1                           Grange Park
# 2         Crunch Fitness - College Park
# 3                  Clarence Square Park
# 4                         One Park Lane
# 5     St. Andrews Playground / Dog Park
# 6                Trinity Bellwoods Park
# 7                          Queen's Park
# 8                  Bellevue Square Park
# 9                           Berczy Park
# 10                             HTO Park
# 11  GoodLife Fitness Toronto Bloor Park
# 12     Residences at College Park North
# 13   TTC Streetcar #403 - Victoria park
# 14                            High Park
# 15               Parliament Square Park
# 16                  Riverdale Park West
# 17               Physiomed College Park
# 18                  Riverdale Park East
# 19     Toothworks - College Park Dental
# 20              Cawthra Square Dog Park
# 21                      Winchester Park
# 22                         Stanley Park
# 23              Stanley Park (Dog Park)
# 24                   Battery Park Tower
# 25         Victoria Park Subway Station
# 26                      Coronation Park
# 27         Orphan's Greenspace Dog Park
# 28                   Canoe Landing Park
# 29                    Barbara Hall Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                       Gym / Fitness Center              382 Yonge Street
# 3                                       Park                   Spadina Ave
# 4   Residential Building (Apartment / Condo)                 280 Simcoe St
# 5                                       Park      450 Adelaide Street West
# 6                                       Park            1053 Dundas St. W.
# 7                                       Park               University Ave.
# 8                                       Park  btwn Bellevue & Augusta Ave.
# 9                                       Park        35 Wellington St. East
# 10                                      Park                  Queen's Quay
# 11                                       Gym                     8 Park Rd
# 12  Residential Building (Apartment / Condo)                   763 Bay St.
# 13                        Light Rail Station                           NaN
# 14                                      Park              1873 Bloor St. W
# 15                                      Park          44 Parliament Street
# 16                                      Park               500 Gerrard St.
# 17                            Medical Center                  382 Yonge St
# 18                                      Park             550 Broadview Ave
# 19                          Dentist's Office        444 Yonge St, Unit M16
# 20                                   Dog Run                519 Church St.
# 21                                Playground            530 Ontario Street
# 22                                      Park              King Street West
# 23                                   Dog Run              King Street West
# 24  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 25                             Metro Station         777 Victoria Park Ave
# 26                                      Park        711 Lake Shore Blvd. W
# 27                                   Dog Run                  51 Power St.
# 28                                      Park             50 Fort York Blvd
# 29                                      Park                 519 Church St
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.659263 -79.382632    M5G 1S8    ON
# 3   43.644222 -79.394230        NaN    ON
# 4   43.655442 -79.390056    M5T 2Y5    ON
# 5   43.647388 -79.398752        NaN    ON
# 6   43.647072 -79.413756    M5H 2N2    ON
# 7   43.663946 -79.392180    M5R 2E8    ON
# 8   43.653610 -79.402199    M5T 2N4    ON
# 9   43.648048 -79.375172        NaN    ON
# 10  43.637949 -79.387820        NaN    ON
# 11  43.671398 -79.384408    M4W 3G8    ON
# 12  43.659822 -79.385159    M5G 2R3    ON
# 13  43.650735 -79.386921        NaN    ON
# 14  43.646479 -79.463425    M6R 2Z3    ON
# 15  43.650264 -79.362195        NaN    ON
# 16  43.666048 -79.360941    M5A 2H3    ON
# 17  43.658528 -79.382169    M5B 1S8    ON
# 18  43.669951 -79.355493    M4K 2P1    ON
# 19  43.660009 -79.383905        NaN    ON
# 20  43.666583 -79.380040        NaN    ON
# 21  43.666231 -79.371631        NaN    ON
# 22  43.642395 -79.409330        NaN    ON
# 23  43.641668 -79.409269        NaN    ON
# 24  43.639024 -79.415510    M6K 3R9    ON
# 25  43.694883 -79.288735    M4B 2E2    ON
# 26  43.634553 -79.405403    M5V 3T7    ON
# 27  43.654654 -79.362501        NaN    ON
# 28  43.638762 -79.397067    M5V 3Z1    ON
# 29  43.666879 -79.381068    M4Y 2K9    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                    name  \
# 0           Queen's Park Subway Station
# 2         Crunch Fitness - College Park
# 4                         One Park Lane
# 6                Trinity Bellwoods Park
# 7                          Queen's Park
# 8                  Bellevue Square Park
# 11  GoodLife Fitness Toronto Bloor Park
# 12     Residences at College Park North
# 14                            High Park
# 16                  Riverdale Park West
# 17               Physiomed College Park
# 18                  Riverdale Park East
# 24                   Battery Park Tower
# 25         Victoria Park Subway Station
# 26                      Coronation Park
# 28                   Canoe Landing Park
# 29                    Barbara Hall Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 2                       Gym / Fitness Center              382 Yonge Street
# 4   Residential Building (Apartment / Condo)                 280 Simcoe St
# 6                                       Park            1053 Dundas St. W.
# 7                                       Park               University Ave.
# 8                                       Park  btwn Bellevue & Augusta Ave.
# 11                                       Gym                     8 Park Rd
# 12  Residential Building (Apartment / Condo)                   763 Bay St.
# 14                                      Park              1873 Bloor St. W
# 16                                      Park               500 Gerrard St.
# 17                            Medical Center                  382 Yonge St
# 18                                      Park             550 Broadview Ave
# 24  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 25                             Metro Station         777 Victoria Park Ave
# 26                                      Park        711 Lake Shore Blvd. W
# 28                                      Park             50 Fort York Blvd
# 29                                      Park                 519 Church St
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 2   43.659263 -79.382632    M5G 1S8    ON
# 4   43.655442 -79.390056    M5T 2Y5    ON
# 6   43.647072 -79.413756    M5H 2N2    ON
# 7   43.663946 -79.392180    M5R 2E8    ON
# 8   43.653610 -79.402199    M5T 2N4    ON
# 11  43.671398 -79.384408    M4W 3G8    ON
# 12  43.659822 -79.385159    M5G 2R3    ON
# 14  43.646479 -79.463425    M6R 2Z3    ON
# 16  43.666048 -79.360941    M5A 2H3    ON
# 17  43.658528 -79.382169    M5B 1S8    ON
# 18  43.669951 -79.355493    M4K 2P1    ON
# 24  43.639024 -79.415510    M6K 3R9    ON
# 25  43.694883 -79.288735    M4B 2E2    ON
# 26  43.634553 -79.405403    M5V 3T7    ON
# 28  43.638762 -79.397067    M5V 3Z1    ON
# 29  43.666879 -79.381068    M4Y 2K9    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 6   Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 7             Queen's Park       Park               University Ave.
# 8     Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 14               High Park       Park              1873 Bloor St. W
# 16     Riverdale Park West       Park               500 Gerrard St.
# 18     Riverdale Park East       Park             550 Broadview Ave
# 26         Coronation Park       Park        711 Lake Shore Blvd. W
# 28      Canoe Landing Park       Park             50 Fort York Blvd
# 29       Barbara Hall Park       Park                 519 Church St
#
#           lat        lng postalCode state
# 6   43.647072 -79.413756    M5H 2N2    ON
# 7   43.663946 -79.392180    M5R 2E8    ON
# 8   43.653610 -79.402199    M5T 2N4    ON
# 14  43.646479 -79.463425    M6R 2Z3    ON
# 16  43.666048 -79.360941    M5A 2H3    ON
# 18  43.669951 -79.355493    M4K 2P1    ON
# 26  43.634553 -79.405403    M5V 3T7    ON
# 28  43.638762 -79.397067    M5V 3Z1    ON
# 29  43.666879 -79.381068    M4Y 2K9    ON

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G3PM1X3BYS0RGSYFU0PUEIS0XQV3OLXKX00UGE1AANRJIQQP&client_secret=U3EMAUUDX5H343WX41RCCVANFDAVJSQHE0RVN4INQGN2TGUC&ll=43.653963,-79.387207&v=20190611&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 2  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 2  4ad4c05cf964a520dff520e3       301 Front St W          CA       Toronto
# 3  4b072e9df964a52009f922e3     280 Spadina Ave.          CA       Toronto
# 4  4b266f05f964a520657b24e3      266 Spadina Ave          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                145
# 1           Canada        at D'Arcy St.                922
# 2           Canada      301 Front St. W               1271
# 3           Canada     at Dundas St. W.                892
# 4           Canada       at Willison Sq                892
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 2  [301 Front St W (301 Front St. W), Toronto ON ...
# 3  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
# 4  [266 Spadina Ave (at Willison Sq), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 2  [{'label': 'display', 'lat': 43.64253731714456...     43.642537
# 3  [{'label': 'display', 'lat': 43.65278331265585...     43.652783
# 4  [{'label': 'display', 'lat': 43.6522783893466,...     43.652278
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.385931                   NaN             M5G 1R3             ON
# 1    -79.398650     Kensington Market             M5T 2E9             ON
# 2    -79.387042                   NaN             M5V 2T6             ON
# 3    -79.398174                   NaN                 NaN             ON
# 4    -79.398039                   NaN             M5T 2E4             ON
#
#                                  name    referralId venuePage.id
# 0     Hemispheres Restaurant & Bistro  v-1560280682          NaN
# 1              Rol San Restaurant 龍笙棧  v-1560280682          NaN
# 2                      360 Restaurant  v-1560280682          NaN
# 3  Sky Dragon Chinese Restaurant 龍翔酒樓  v-1560280682          NaN
# 4      Goldstone Noodle Restaurant 金石  v-1560280682          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0     Hemispheres Restaurant & Bistro  American Restaurant
# 1              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 2                      360 Restaurant             Wine Bar
# 3  Sky Dragon Chinese Restaurant 龍翔酒樓   Dim Sum Restaurant
# 4      Goldstone Noodle Restaurant 金石         Noodle House
#
#                address  cc     city country       crossStreet  distance  \
# 0  110 Chestnut Street  CA  Toronto  Canada               NaN       145
# 1     323 Spadina Ave.  CA  Toronto  Canada     at D'Arcy St.       922
# 2       301 Front St W  CA  Toronto  Canada   301 Front St. W      1271
# 3     280 Spadina Ave.  CA  Toronto  Canada  at Dundas St. W.       892
# 4      266 Spadina Ave  CA  Toronto  Canada    at Willison Sq       892
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 2  [301 Front St W (301 Front St. W), Toronto ON ...
# 3  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
# 4  [266 Spadina Ave (at Willison Sq), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 2  [{'label': 'display', 'lat': 43.64253731714456...  43.642537 -79.387042
# 3  [{'label': 'display', 'lat': 43.65278331265585...  43.652783 -79.398174
# 4  [{'label': 'display', 'lat': 43.6522783893466,...  43.652278 -79.398039
#
#         neighborhood postalCode state                        id
# 0                NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1  Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 2                NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3
# 3                NaN        NaN    ON  4b072e9df964a52009f922e3
# 4                NaN    M5T 2E4    ON  4b266f05f964a520657b24e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 2                                   360 Restaurant                 Wine Bar
# 3               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 4                   Goldstone Noodle Restaurant 金石             Noodle House
# 5                            Victoria's Restaurant               Restaurant
# 6                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 7                           Azure Restaurant & Bar               Restaurant
# 8                    Green Tea Restaurant Downtown       Chinese Restaurant
# 9   Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 10                  The Hot House Restaurant & Bar      American Restaurant
# 11                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 12                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 13              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 14                    Aroma Fine Indian Restaurant        Indian Restaurant
# 15                         Victor Restaurant & Bar                      Bar
# 16                        Ka Chi Korean Restaurant        Korean Restaurant
# 17             Richtree Natural Market Restaurants               Restaurant
# 18                  Insomnia Restaurant and Lounge               Restaurant
# 19                      Matisse Restaurant And Bar               Restaurant
# 20                     Woodlot Restaurant & Bakery  New American Restaurant
# 21               El Rancho Restaurant & Night Club                Nightclub
# 22                               Tundra Restaurant               Restaurant
# 23                            Montecito Restaurant               Restaurant
# 24                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 25                         Little India Restaurant        Indian Restaurant
# 26         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 27                           ONE Restaurant/Lounge  New American Restaurant
# 28                         The Lakeview Restaurant                    Diner
# 29               Kensington Cornerstone Restaurant           Breakfast Spot
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 2                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 3                  280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 4                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 5               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 6                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 7                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 8   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 9             100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 10                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 11                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 12                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 13                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 14                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 15                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 16                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 17                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 18                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 19                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 20              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 21                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 22         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 23                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 24           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 25                  255 Queen St. W  43.650319 -79.388998    M5V 1Z4    ON
# 26                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 27                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 28                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 29               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 2                                   360 Restaurant                 Wine Bar
# 4                   Goldstone Noodle Restaurant 金石             Noodle House
# 5                            Victoria's Restaurant               Restaurant
# 6                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 7                           Azure Restaurant & Bar               Restaurant
# 8                    Green Tea Restaurant Downtown       Chinese Restaurant
# 9   Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 10                  The Hot House Restaurant & Bar      American Restaurant
# 11                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 12                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 14                    Aroma Fine Indian Restaurant        Indian Restaurant
# 15                         Victor Restaurant & Bar                      Bar
# 16                        Ka Chi Korean Restaurant        Korean Restaurant
# 17             Richtree Natural Market Restaurants               Restaurant
# 18                  Insomnia Restaurant and Lounge               Restaurant
# 19                      Matisse Restaurant And Bar               Restaurant
# 20                     Woodlot Restaurant & Bakery  New American Restaurant
# 21               El Rancho Restaurant & Night Club                Nightclub
# 22                               Tundra Restaurant               Restaurant
# 23                            Montecito Restaurant               Restaurant
# 24                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 25                         Little India Restaurant        Indian Restaurant
# 26         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 28                         The Lakeview Restaurant                    Diner
# 29               Kensington Cornerstone Restaurant           Breakfast Spot
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 2                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 4                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 5               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 6                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 7                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 8   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 9             100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 10                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 11                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 12                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 14                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 15                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 16                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 17                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 18                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 19                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 20              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 21                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 22         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 23                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 24           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 25                  255 Queen St. W  43.650319 -79.388998    M5V 1Z4    ON
# 26                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 28                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 29               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON

# %%
# create dataframe of Hotel, Park and Restaurant
park_neighbourhood_df = pd.concat([df_hotel, df_park, df_Restaurant,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name               categories  \
# 0                    Sheraton Centre Toronto Hotel                    Hotel
# 1                                   Grand Ballroom              Event Space
# 2                           Trinity Bellwoods Park                     Park
# 3                                     Queen's Park                     Park
# 4                             Bellevue Square Park                     Park
# 5                                        High Park                     Park
# 6                              Riverdale Park West                     Park
# 7                              Riverdale Park East                     Park
# 8                                  Coronation Park                     Park
# 9                               Canoe Landing Park                     Park
# 10                               Barbara Hall Park                     Park
# 11                 Hemispheres Restaurant & Bistro      American Restaurant
# 12                          Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 13                                  360 Restaurant                 Wine Bar
# 14                  Goldstone Noodle Restaurant 金石             Noodle House
# 15                           Victoria's Restaurant               Restaurant
# 16                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 17                          Azure Restaurant & Bar               Restaurant
# 18                   Green Tea Restaurant Downtown       Chinese Restaurant
# 19  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 20                  The Hot House Restaurant & Bar      American Restaurant
# 21                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 22                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 23                    Aroma Fine Indian Restaurant        Indian Restaurant
# 24                         Victor Restaurant & Bar                      Bar
# 25                        Ka Chi Korean Restaurant        Korean Restaurant
# 26             Richtree Natural Market Restaurants               Restaurant
# 27                  Insomnia Restaurant and Lounge               Restaurant
# 28                      Matisse Restaurant And Bar               Restaurant
# 29                     Woodlot Restaurant & Bakery  New American Restaurant
# 30               El Rancho Restaurant & Night Club                Nightclub
# 31                               Tundra Restaurant               Restaurant
# 32                            Montecito Restaurant               Restaurant
# 33                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 34                         Little India Restaurant        Indian Restaurant
# 35         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 36                         The Lakeview Restaurant                    Diner
# 37               Kensington Cornerstone Restaurant           Breakfast Spot
#
#                             address        lat        lng postalCode state
# 0             123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 1                   123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 2                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 3                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 4      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 5                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 6                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 7                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 8            711 Lake Shore Blvd. W  43.634553 -79.405403    M5V 3T7    ON
# 9                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 10                    519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 11              110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 12                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 13                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 14                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 15              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 16                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 17                    225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 18  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 19            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 20                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 21                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 22                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 23                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 24                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 25                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 26                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 27                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 28                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 29              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 30                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 31         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 32                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 33           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 34                  255 Queen St. W  43.650319 -79.388998    M5V 1Z4    ON
# 35                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 36                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 37               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON

# %%
# Generate map to visualize Hotel, Park and Restaurant
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
